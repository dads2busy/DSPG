# %% [markdown]
# ### Imports

# %%
import os
import psycopg2 as pg


#bert
from sentence_transformers import SentenceTransformer, util
import torch

import pandas as pd

import re

import nltk
nltk.download("punkt")

from nltk import tokenize

import scipy

import datetime

# %% [markdown]
# ### Data

# %%
# unlabeled repo data
repo_data = pd.read_csv("~/git/dspg21oss/data/dspg21oss/clean_eng_github_repos_157k.csv")

repo_description = repo_data["description"].tolist()

# %%
validated_data = pd.read_csv('~/git/dspg21oss/data/dspg21oss/oss_software_labelled.csv') #import csv

# %%
validated_data.head()
# Out:
#                        slug  ai_label  topics_ai  blockchain_label  \
# 0         tensorflow/models       1.0        1.0               NaN
# 1  huggingface/transformers       1.0        2.0               NaN
# 2      google-research/bert       1.0        1.0               NaN
# 3         ageron/handson-ml       1.0        1.0               NaN
# 4           explosion/spaCy       1.0        1.0               NaN
#
#    app_blockchain_all  clang_label  prog_clang  database_label  \
# 0                 NaN          NaN         NaN             NaN
# 1                 NaN          NaN         NaN             NaN
# 2                 NaN          NaN         NaN             NaN
# 3                 NaN          NaN         NaN             NaN
# 4                 NaN          NaN         NaN             NaN
#
#    app_database_all  dataviz_label  topics_dataviz  java_label  prog_java  \
# 0               NaN            NaN             NaN         NaN        NaN
# 1               NaN            NaN             NaN         NaN        NaN
# 2               NaN            NaN             NaN         NaN        NaN
# 3               NaN            NaN             NaN         NaN        NaN
# 4               NaN            NaN             NaN         NaN        NaN
#
#    javascript_label  prog_javascript  php_label  prog_php  python_label  \
# 0               NaN              NaN        NaN       NaN           1.0
# 1               NaN              NaN        NaN       NaN           1.0
# 2               NaN              NaN        NaN       NaN           NaN
# 3               NaN              NaN        NaN       NaN           1.0
# 4               NaN              NaN        NaN       NaN           1.0
#
#    prog_python
# 0          1.0
# 1          1.0
# 2          NaN
# 3          3.0
# 4          1.0
