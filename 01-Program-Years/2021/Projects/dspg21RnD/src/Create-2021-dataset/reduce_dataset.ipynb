# %% [markdown]
# This code reduces the size of the full dataset by removing columns with intermediate NLP processing steps from Summer 2020.

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)

import pickle

# %%
# full corpus

df = pd.read_pickle("../../../publicrd/data/prd/Federal_RePORTER/FR-cleaned-2021FEB24.pkl")

# %%
df.shape
# Out:
# (690814, 40)

# %%
df.head()
# Out:
#    index  original index PROJECT_ID  \
# 0      0           17608     152242
# 1      1          111864     190316
# 2      2           22052     154213
# 3      3           35004     159362
# 4      4          371628     594482
#
#                                             ABSTRACT    FY  ORG_COUNT  \
# 0  The multiprotein complex y-secretase proteolyt...  2008          1
# 1  DESCRIPTION (provided by applicant):   The Kis...  2008          1
# 2  DESCRIPTION (provided by applicant): The objec...  2008          1
# 3  Obesity is the cause of many adverse pregnancy...  2008          1
# 4  Local potato advisory groups have expressed in...  2010          1
#
#    PI_COUNT                                   working_abstract Start_Char  \
# 0         1  The multiprotein complex y-secretase proteolyt...          T
# 1         1  The Kissl gene encodes peptides called kisspep...          T
# 2         1  The objective of this research is to understan...          T
# ...

# %%
df.columns
# Out:
# Index(['index', 'original index', 'PROJECT_ID', 'ABSTRACT', 'FY', 'ORG_COUNT',
#        'PI_COUNT', 'working_abstract', 'Start_Char', 'nchar', 'LAST_CHAR',
#        'lemma_abstract', 'clean_lemmas', 'stopwds_removed', 'n_grams_added',
#        'final_tokens', 'final_frqwds_removed', 'PROJECT_TERMS',
#        'PROJECT_TITLE', 'DEPARTMENT', 'AGENCY', 'IC_CENTER', 'PROJECT_NUMBER',
#        'PROJECT_START_DATE', 'PROJECT_END_DATE', 'CONTACT_PI_PROJECT_LEADER',
#        'OTHER_PIS', 'CONGRESSIONAL_DISTRICT', 'DUNS_NUMBER',
#        'ORGANIZATION_NAME', 'ORGANIZATION_CITY', 'ORGANIZATION_STATE',
#        'ORGANIZATION_ZIP', 'ORGANIZATION_COUNTRY', 'BUDGET_START_DATE',
#        'BUDGET_END_DATE', 'CFDA_CODE', 'FY.y', 'FY_TOTAL_COST',
#        'FY_TOTAL_COST_SUB_PROJECTS'],
#       dtype='object')

# %%
smaller_df = df.drop(columns=['index', 'working_abstract', 'Start_Char', 'LAST_CHAR', 'lemma_abstract', \
                              'clean_lemmas', 'n_grams_added'])

# %%
smaller_df.head()
# Out:
#    original index PROJECT_ID  \
# 0           17608     152242
# 1          111864     190316
# 2           22052     154213
# 3           35004     159362
# 4          371628     594482
#
#                                             ABSTRACT    FY  ORG_COUNT  \
# 0  The multiprotein complex y-secretase proteolyt...  2008          1
# 1  DESCRIPTION (provided by applicant):   The Kis...  2008          1
# 2  DESCRIPTION (provided by applicant): The objec...  2008          1
# 3  Obesity is the cause of many adverse pregnancy...  2008          1
# 4  Local potato advisory groups have expressed in...  2010          1
#
#    PI_COUNT  nchar                                    stopwds_removed  \
# 0         1   1402  [multiprotein, complex, y-secretase, proteolyt...
# 1         1   2553  [kissl, gene, encode, peptide, kisspeptin, bin...
# 2         1   1414  [objective, research, understand, biophysical,...
# 3         1   1545  [obesity, cause, adverse, pregnancyoutcome, re...
# ...

# %%
# save smaller corpus

smaller_df.to_pickle("./smaller-final-dataset2.pkl")
