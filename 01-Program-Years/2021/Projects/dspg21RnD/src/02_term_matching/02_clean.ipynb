# %% [markdown]
# # Clean up some space by only saving AI related abstract in the csv

# %%
import pandas as pd
import numpy as np

# %%
# Data 1
nterms_matched = pd.read_csv("/home/zz3hs/git/dspg21RnD/data/dspg21RnD/nterm_matched_abstracts.csv") #import csv

nterms_matched
# Out:
# /apps/software/standard/core/anaconda/2020.11-py3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (16,18,19,20,27,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
nterms_matched['IS_AI'].replace('[]', np.nan, inplace=True)
nterms_matched

ai_abstracts = nterms_matched[nterms_matched["IS_AI"].notnull()]
#ai_abstracts.to_csv(r'/project/class/bii_sdad_dspg/uva_2021/dspg21RnD/nterm_matched_ai_abstracts.csv', index = False)

# %%
# Data 2
term_matched_final = pd.read_csv("/home/zz3hs/git/dspg21RnD/data/dspg21RnD/term_matched_abstracts_final.csv") #import csv
# Out:
# /apps/software/standard/core/anaconda/2020.11-py3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9,12,14,15,16,22,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
term_matched_final
# Out:
#          index  original index  PROJECT_ID  \
# 0            0           17608    152242.0
# 1            1          111864    190316.0
# 2            2           22052    154213.0
# 3            3           35004    159362.0
# 4            4          371628    594482.0
# ...        ...             ...         ...
# 690809  690850         1034758   1126666.0
# 690810  690851         1074034   1109788.0
# 690811  690852         1029450   1038442.0
# 690812  690853         1074409   1154490.0
# 690813  690854         1007201   1009631.0
#
#                                                  ABSTRACT    FY  \
# 0       The multiprotein complex y-secretase proteolyt...  2008
# 1       DESCRIPTION (provided by applicant):   The Kis...  2008
# 2       DESCRIPTION (provided by applicant): The objec...  2008
# 3       Obesity is the cause of many adverse pregnancy...  2008
# 4       Local potato advisory groups have expressed in...  2010
# ...

# %%
#term_matched_final.drop(term_matched_final[term_matched_final['IS_AI'] == False].index, inplace=True)
ai_abstracts = term_matched_final[term_matched_final["IS_AI"].str.contains("False")==False]

# %%
#ai_abstracts.to_csv(r'/project/class/bii_sdad_dspg/uva_2021/dspg21RnD/term_matched_ai_abstracts_final.csv', index = False)
