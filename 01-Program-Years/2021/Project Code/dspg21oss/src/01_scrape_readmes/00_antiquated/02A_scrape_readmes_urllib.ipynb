# %% [markdown]
# ### GitHub README Extraction
#
# During this summer, the DSGP OSS 2021 team willbe classifying GitHub repositores into different software types. To do this, we will be extracting README files from all of the OSS repos (i.e. those with OSS licenses) and then developing NLP techniques to classify those repos. In this file, we document the extraction process for GitHub README files.
#
# First, we load our packages

# %%
# load packages 
import os
import glob
import psycopg2 as pg
from sqlalchemy import create_engine
import pandas as pd
import requests as r
import string 
import json
import base64
import urllib.request
import urllib.error
import itertools 
import traceback
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import time
from functools import wraps
import urllib.request
import multiprocessing
from multiprocessing.pool import ThreadPool as Pool
from retrying import retry
from datetime import datetime

print("ready")
# Out:
# ready

# %% [markdown]
# Next, we will grab our data from the database.

# %%
# connect to the database, download data 
connection = pg.connect(host = 'postgis1', database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

raw_slug_data = '''SELECT * FROM gh_2007_2020.repos_ranked where commits > 1000  '''

# convert to a dataframe, show how many missing we have (none)
raw_slug_data = pd.read_sql_query(raw_slug_data, con=connection)
raw_slug_data.head()
# Out:
#                                  id     spdx                   slug  \
# 0  MDEwOlJlcG9zaXRvcnk5NDkwMTU1Mw==  ECL-2.0     juancho85/opencast
# 1  MDEwOlJlcG9zaXRvcnkxMzEwNzEzMjk=  GPL-2.0      jeffrizzo/openocd
# 2  MDEwOlJlcG9zaXRvcnkzMDk5NTI1MA==      MIT        supcoin/supcoin
# 3  MDEwOlJlcG9zaXRvcnk5MjE4NDg3Mg==  GPL-3.0  bigearth/clone-marlin
# 4  MDEwOlJlcG9zaXRvcnkxMzc2NjEyMTE=  GPL-2.0         gemian/connman
#
#             createdat                                        description  \
# 0 2017-06-20 14:39:56  The free and open source solution for automate...
# 1 2018-04-25 22:42:24                                    openocd patches
# 2 2015-02-19 00:47:12  Supcoin release wallet (NOTE: will not sync un...
# 3 2017-05-23 14:50:32                               Clone's marlin build
# 4 2018-06-17 14:30:28  Connection Manager - building 'master' for bot...
#
#   primarylanguage                                        branch  commits  \
# 0            Java  MDM6UmVmOTQ5MDE1NTM6cmVmcy9oZWFkcy9kZXZlbG9w     7715
# 1               C  MDM6UmVmMTMxMDcxMzI5OnJlZnMvaGVhZHMvbWFzdGVy     7714
# 2             C++  MDM6UmVmMzA5OTUyNTA6cmVmcy9oZWFkcy9tYXN0ZXI=     7709
# 3               C  MDM6UmVmOTIxODQ4NzI6cmVmcy9oZWFkcy9tYXN0ZXI=     7707
# 4               C  MDM6UmVmMTM3NjYxMjExOnJlZnMvaGVhZHMvbWFzdGVy     7707
#
#                  asof status
# 0 2021-01-03 15:59:42   Done
# 1 2021-01-03 18:44:52   Done
# 2 2021-01-03 15:54:35   Done
# 3 2021-01-03 20:04:50   Done
# 4 2021-01-03 18:02:13   Done

# %%
raw_slug_data['slug'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4b2d44cb5086> in <module>
# ----> 1 raw_slug_data['slug'].count()
#
# NameError: name 'raw_slug_data' is not defined

# %%
# exp multiplier that waits 30 seconds, then 30 secs + 30 secs, etc until 5 tries is over 
@retry(stop_max_attempt_number=5, wait_exponential_multiplier=30000, wait_exponential_max=30000) 
def scrape_slugs(slug):
    ''' Scrapes slugs with multiple threads '''
    url = f'https://github.com/{slug}#readme'
    split_slugs = slug.split("/")
    login = split_slugs[0]
    repo = split_slugs[1]
    fullfilename = os.path.join('/project/class/bii_sdad_dspg/ncses_oss_2021/', f'readme_{login}_{repo}.txt')
    urllib.request.urlretrieve(url, fullfilename)
    now = datetime.now()
    current_time = now.strftime("%Y-%m-%d %H:%M:%S")
    return slug, current_time, "Done"

# %%
# exp multiplier that waits 30 seconds, then 30 secs + 30 secs, etc until 5 tries is over 
@retry(stop_max_attempt_number=5, wait_exponential_multiplier=30000, wait_exponential_max=30000) 
def scrape_slugs(slug):
    ''' Scrapes slugs with multiple threads '''
    url = f'https://github.com/{slug}#readme'
    split_slugs = slug.split("/")
    login = split_slugs[0]
    repo = split_slugs[1]
    fullfilename = os.path.join('/project/class/bii_sdad_dspg/ncses_oss_2021/', f'readme_{login}_{repo}.txt')
    try: 
        urllib.request.urlretrieve(url, fullfilename)
    except: urllib.HTTPError, e:
        checksLogger.error('HTTPError = ' + str(e.code))
    except urllib.URLError, e:
        checksLogger.error('URLError = ' + str(e.reason))
    except httplib.HTTPException, e:
        checksLogger.error('HTTPException')
    except Exception:
        checksLogger.error('generic exception: ' + traceback.format_exc())
    now = datetime.now()
    current_time = now.strftime("%Y-%m-%d %H:%M:%S")
    return slug, current_time, "Done"

# %%
batch = "batch3"

raw_slugs = raw_slug_data["slug"].tolist()
slugs = []
for s in raw_slugs:
    slugs.append(s.strip())

cores_available = multiprocessing.cpu_count() - 1
pool = Pool(cores_available)

logging_slugs = []
logging_time = []
logging_status = []
for result in pool.imap_unordered(scrape_slugs, slugs):
    logging_slugs.append(result[0])
    logging_time.append(result[1])
    logging_status.append(result[2])
    logging_df = pd.DataFrame({'slug': logging_slugs, "batch": batch, 'as_of': logging_time, 'status': logging_status}, 
                              columns=["slug", "batch", "as_of", "status"])
    logging_df.to_csv('/project/class/bii_sdad_dspg/ncses_oss_2021/'+batch+'.csv', index=False)
    print(result)
# Out:
# ('SuperElastix/SimpleElastix', '08:09:15', 'Done')
# ('LivelyKernel/lively.next', '08:09:15', 'Done')
# ('jeffrizzo/openocd', '08:09:15', 'Done')
# ('shitolepriya/test-frappe', '08:09:15', 'Done')
# ('bigearth/clone-marlin', '08:09:15', 'Done')
# ('Rentu/redis-read', '08:09:15', 'Done')
# ('jandockx/ppwcode-recovered-from-google-code', '08:09:15', 'Done')
# ('juancho85/opencast', '08:09:15', 'Done')
# ('paleobiodb/data_service', '08:09:15', 'Done')
# ('gemian/connman', '08:09:15', 'Done')
# ('AltugYildirim/istio', '08:09:15', 'Done')
# ('supcoin/supcoin', '08:09:15', 'Done')
# ('levants/lightmare', '08:09:15', 'Done')
# ('KnothHe/redis-5.0', '08:09:15', 'Done')
# ('mshbeab/anter', '08:09:15', 'Done')
# ('zraul123/keytekia', '08:09:15', 'Done')
# ('ajaysharma00/mastodon', '08:09:15', 'Done')
# ('puneetgkaur/backup_sugar_sugartoolkit', '08:09:15', 'Done')
# ('Lordsm926/l', '08:09:15', 'Done')
# ('addb-swstarlab/ParallelAOF', '08:09:15', 'Done')
# ('keyteki/keyteki', '08:09:15', 'Done')
# ('qingqibing/libcxx', '08:09:15', 'Done')
# ('Shifter78/shitno', '08:09:15', 'Done')
# ('zhangsiqi951016/java-spring-security', '08:09:15', 'Done')
# ('CallistoNetwork/CallistoEtherWallet', '08:09:15', 'Done')
# ('kernelai/pika-cli', '08:09:15', 'Done')
# ('vquentin/scinote-dev', '08:09:15', 'Done')
# ('wrye-bash/wrye-bash', '08:09:15', 'Done')
# ('0x6a77/openocd', '08:09:15', 'Done')
# ('JoelCatantan/ci4cms', '08:09:15', 'Done')
# ('zhang-shengping/test_kolla', '08:09:15', 'Done')
# ('YASHCODE8/CODE-MIRROROR', '08:09:15', 'Done')
# ('unicef/etools-partnership-management', '08:09:15', 'Done')
# ('jackjack821/pytest', '08:09:15', 'Done')
# ('SelfKeyFoundation/Identity-Wallet', '08:09:15', 'Done')
# ('leanprover-community/mathlib', '08:09:15', 'Done')
# ('UniTime/unitime', '08:09:15', 'Done')
# ('CelestiaProject/CelestiaContent', '08:09:15', 'Done')
# ('adamlaska/osmos-cosmos-sdk', '08:09:15', 'Done')
# ('gcampax/mutter', '08:09:16', 'Done')
# ('findsorguk/findsorguk', '08:09:16', 'Done')
# ('dusenberrymw/IBM-SystemML', '08:09:16', 'Done')
# ('sagargohil91/AzureTest', '08:09:16', 'Done')
# ('manjulaRathnayaka/app-cloud', '08:09:16', 'Done')
# ('zsiki/GeoEasy', '08:09:16', 'Done')
# ('andamian/vostools_new', '08:09:16', 'Done')
# ('stephanfeb/bitcoinj-sv', '08:09:16', 'Done')
# ('DamienIrving/ocean-analysis', '08:09:16', 'Done')
# ('NorinAB/saiku', '08:09:16', 'Done')
# ('navidpati/git-github.com-substratum-substratum', '08:09:16', 'Done')
# ('piskvorky/pazpar2', '08:09:16', 'Done')
# ('Bind/my-zsh', '08:09:16', 'Done')
# ('thornbird/dot-oh-my-zsh', '08:09:16', 'Done')
# ('selvankasi/Dont_Waste', '08:09:16', 'Done')
# ('eteran/edb-debugger', '08:09:16', 'Done')
# ('dltsys/dashj', '08:09:16', 'Done')
# ('cristal-ise/cristal-ise', '08:09:16', 'Done')
# ('Markionium/material-components-web', '08:09:16', 'Done')
# ('rjdp/EE-dbmigrate', '08:09:16', 'Done')
# ('rburchell/ck', '08:09:16', 'Done')
# ('galaxiegaming/discord-bot-1', '08:09:16', 'Done')
# ('sauravkumar2014/ASCEND', '08:09:16', 'Done')
# ('tupeloTS/telescopety', '08:09:16', 'Done')
# ('ledermann/docker-rails', '08:09:16', 'Done')
# ('norbusan/mupdf-debian', '08:09:16', 'Done')
# ('joshblack/carbon-experimental', '08:09:16', 'Done')
# ('pageboard/client', '08:09:16', 'Done')
# ('favorinfo/ghost', '08:09:16', 'Done')
# ('mathiaspet/gms', '08:09:16', 'Done')
# ('edquist/autopyfactory', '08:09:16', 'Done')
# ('bingoer/bitcoinj_sourcecode_analysis', '08:09:16', 'Done')
# ('bazurbat/jagen', '08:09:16', 'Done')
# ('IntTeam-24hcode/BoubouGUI', '08:09:16', 'Done')
# ('astronautlevel2/Luma3DS', '08:09:16', 'Done')
# ('gareging/SDN_Framework', '08:09:16', 'Done')
# ('zillerium/sg1', '08:09:16', 'Done')
# ('joansmith/cucumber-jvm', '08:09:16', 'Done')
# ('marcelsavegnago/l10n-brazil-kmee', '08:09:16', 'Done')
# ('Novi890s/doraeminbot1', '08:09:16', 'Done')
# ('Roare/Dawn_of_Light', '08:09:16', 'Done')
# ('irfan-en/cloned-repo', '08:09:16', 'Done')
# ('jopohl/urh', '08:09:16', 'Done')
# ('JohnSnowLabs/spark-nlp', '08:09:16', 'Done')
# ('clear39/avcode-libx264', '08:09:16', 'Done')
# ('RockISI/bitcoin', '08:09:16', 'Done')
# ('fsheik/loungeIRC', '08:09:16', 'Done')
# ('DeMoorJasper/Maltrail', '08:09:16', 'Done')
# ('qqbis/tutorial', '08:09:16', 'Done')
# ('adsharma/libunwind', '08:09:16', 'Done')
# ('drewc/plowshare', '08:09:16', 'Done')
# ('asoltys/bitcoinjs-lib', '08:09:16', 'Done')
# ('dirkwhoffmann/virtualc64', '08:09:16', 'Done')
# ('prevorus/botik', '08:09:16', 'Done')
# ('shinefield/mangoszeroscripts', '08:09:16', 'Done')
# ('joLapss/volumio', '08:09:16', 'Done')
# ('GatorEducator/gatorgrader', '08:09:16', 'Done')
# ('asoltys/elementsjs-lib', '08:09:16', 'Done')
# ('aTonyXiao/packer-templates', '08:09:16', 'Done')
# ('MICommunity/psi-jami', '08:09:16', 'Done')
# ('alanszp/test', '08:09:16', 'Done')
# ('Alphadelta14/jenkins-job-builder', '08:09:16', 'Done')
# ('WebmecanikDev/mautic-docs', '08:10:16', 'Done')
# ('vigour-io/vjs', '08:10:17', 'Done')
# ('AuScope/portal-core', '08:10:17', 'Done')
# ('ttruongatl/fullcalendar', '08:10:17', 'Done')
# ('nexjhealth/x264', '08:10:17', 'Done')
# ('vechain/thor', '08:10:17', 'Done')
# ('kolyshkin/vzctl', '08:10:17', 'Done')
# ('dhkim717/fabric', '08:10:17', 'Done')
# ('nalaswad/nalaswad-closure', '08:10:17', 'Done')
# ('StygianBlues/mbsebbs', '08:10:17', 'Done')
# ('Mirantis/libnetwork', '08:10:17', 'Done')
# ('4minitz/4minitz', '08:10:17', 'Done')
# ('kingdavid72/deepchem', '08:10:17', 'Done')
# ('SchollCenter/SchollCenter.github.io', '08:10:17', 'Done')
# ('jjzhang166/LCUI', '08:10:17', 'Done')
# ('wangyanjunmsn/tinyusb', '08:10:17', 'Done')
# ('jrmuizel/libunwind', '08:10:17', 'Done')
# ('Hydractify/forgottenserver', '08:10:17', 'Done')
# ('codeforamerica/brigade', '08:10:17', 'Done')
# ('joseluis2g/forgottenkarmia', '08:10:17', 'Done')
# ('Emmetttt/OT', '08:10:17', 'Done')
# ('sagpant/forgottenserver', '08:10:17', 'Done')
# ('oaplatform/oap', '08:10:17', 'Done')
# ('TimPaulk/my_instapy', '08:10:17', 'Done')
# ('luispuerto/luispuerto.net', '08:10:17', 'Done')
# ('hathach/tinyusb', '08:10:17', 'Done')
# ('daskeyboard/daskeyboard.io', '08:10:17', 'Done')
# ('zxware/forgottenserver', '08:10:17', 'Done')
# ('macdaddy12561/fhir-server', '08:10:17', 'Done')
# ('ProgrammingLife2017/hygene', '08:10:17', 'Done')
# ('tyndy125/tfs-oficial', '08:10:17', 'Done')
# ('ravigupta112/laravel-timegrid', '08:10:17', 'Done')
# ('ergoemacs/ergoemacs-mode', '08:10:17', 'Done')
# ('justots/forgottenserver', '08:10:17', 'Done')
# ('nagyistoce/netzob', '08:10:17', 'Done')
# ('otland/forgottenserver', '08:10:17', 'Done')
# ('MixinNetwork/ios-app', '08:10:17', 'Done')
# ('dongruibing1614/lombok', '08:10:17', 'Done')
# ('vyakymenko/angular-seed-express', '08:10:17', 'Done')
# ('Chuch2dope/test', '08:10:17', 'Done')
# ('lysevi/dariadb', '08:10:17', 'Done')
# ('amerlyq/airy', '08:10:17', 'Done')
# ('grayarea11235/enki2', '08:10:17', 'Done')
# ('jimmyleray/Emendare', '08:10:17', 'Done')
# ('cymbiotica/ROM-mud', '08:10:17', 'Done')
# ('DingZefang/buginn', '08:10:17', 'Done')
# ('studiomobile/poppler_iphone', '08:10:17', 'Done')
# ('MasoniteFramework/masonite', '08:10:17', 'Done')
# ('stickz/Redstone', '08:10:17', 'Done')
# ('msart/gitg', '08:10:17', 'Done')
# ('tyndy125/7.72-', '08:10:17', 'Done')
# ('koktf23/libsndfile', '08:10:17', 'Done')
# ('mjs973b/jukebox', '08:10:17', 'Done')
# ('metaborg/spoofax-eclipse', '08:10:17', 'Done')
# ('miRkwood-RNA/miRkwood', '08:10:17', 'Done')
# ('aauer1/tinyusb', '08:10:17', 'Done')
# ('jonasoreland/runnerup', '08:10:17', 'Done')
# ('pengqing1995/less', '08:10:17', 'Done')
# ('arunsarat/odl-netvirt', '08:10:17', 'Done')
# ('xDyN/PokemonGo-Bot1311', '08:10:17', 'Done')
# ('ARMmbed/mbed-os-tools', '08:10:17', 'Done')
# ('thiagoblima/math-board-converter', '08:10:17', 'Done')
# ('heyitsmdr/arcadiamud', '08:10:17', 'Done')
# ('clChenLiang/temp-vue-sc', '08:10:17', 'Done')
# ('yumingfei/virt-manager', '08:10:17', 'Done')
# ('seanohue/replicantery', '08:10:17', 'Done')
# ('AtScaleInc/Impala', '08:10:17', 'Done')
# ('rr-/dotfiles', '08:10:17', 'Done')
# ('nelsonsbrian/ranviermud', '08:10:17', 'Done')
# ('archlinux/archweb', '08:10:17', 'Done')
# ('ABaldwinHunter/sinatra-classic', '08:10:17', 'Done')
# ('RanvierMUD/ranviermud', '08:10:17', 'Done')
# ('kernsuite-debian/git-buildpackage', '08:10:17', 'Done')
# ('llovo-code/python-plotly', '08:10:17', 'Done')
# ('RanvierMUD/tiny', '08:10:17', 'Done')
# ('mjshuff23/myMud', '08:10:17', 'Done')
# ('Zachac/RanvierMUD-Experiments', '08:10:17', 'Done')
# ('viktharien/RM', '08:10:17', 'Done')
# ('dr3mro/plowshare', '08:10:18', 'Done')
# ('srivasta/debian.packaging.make-doc', '08:10:18', 'Done')
# ('bishnuprasad/dkan_imported', '08:10:18', 'Done')
# ('palmermarc/vampirewars', '08:10:18', 'Done')
# ('KipperIalovskii/buttsv5', '08:10:18', 'Done')
# ('1ucian0/qiskit-terra-fuzz', '08:10:18', 'Done')
# ('openstack/taskflow', '08:10:18', 'Done')
# ('dondelelcaro/debbugs', '08:10:18', 'Done')
# ('blackflux/lambda-monitor', '08:10:18', 'Done')
# ('WPN-XM/registry', '08:10:18', 'Done')
# ('arifakhriwilaga/masskredit', '08:10:18', 'Done')
# ('nelsonsbrian/testMud', '08:10:18', 'Done')
# ('ganeshghimire1986/VIC', '08:10:18', 'Done')
# ('ygelfand/errbit', '08:10:18', 'Done')
# ('wso2/andes', '08:10:18', 'Done')
# ('FoOtY/ClassyWoW', '08:10:18', 'Done')
# ('dankamongmen/dankcheese', '08:10:18', 'Done')
# ('chaso137/wot-xvm', '08:10:18', 'Done')
# ('pflanze/util-vserver', '08:10:18', 'Done')
# ('rockbaaska/wot-xvm', '08:10:18', 'Done')
# ('nus-ncl/services-in-one', '08:10:18', 'Done')
# ('BuiltBrokenModding/ICBM-2', '08:10:18', 'Done')
# ('detekt/detekt', '08:10:18', 'Done')
# ('ideacatalyst/Huginn', '08:10:18', 'Done')
# ('asaf53409/aa', '08:10:18', 'Done')
# ('rirror/bugs.debian.org', '08:10:18', 'Done')
# ('berigei/kactus2dev', '08:10:18', 'Done')
# ('PureSolTechnologies/Purifinity', '08:10:18', 'Done')
# ('novartema/Chart.js', '08:10:18', 'Done')
# ('goldstar-zsy/telegraf', '08:10:18', 'Done')
# ('g0v-data/aec', '08:10:18', 'Done')
# ('nobody-z/iptables', '08:10:18', 'Done')
# ('mrthuanvn/wot-xvm', '08:10:18', 'Done')
# ('kkman2008/coder-Leetcode', '08:10:18', 'Done')
# ('starling021/uh', '08:10:18', 'Done')
# ('dcgavril/Booked', '08:10:18', 'Done')
# ('sathyanlm/k3', '08:10:18', 'Done')
# ('Mummut/wot-xvm', '08:10:18', 'Done')
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-12-8f7eb989cdf2> in <module>
#      24 logging_time = []
#      25 logging_status = []
# ---> 26 for result in pool.imap_unordered(scrape_slugs, slugs):
#      27     logging_slugs.append(result[0])
#      28     logging_time.append(result[1])
#
# ~/.conda/envs/brandon_env/lib/python3.9/multiprocessing/pool.py in next(self, timeout)
#     868         if success:
#     869             return value
# --> 870         raise value
#     871
#     872     __next__ = next                    # XXX
#
# ~/.conda/envs/brandon_env/lib/python3.9/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/.conda/envs/brandon_env/lib/python3.9/site-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~/.conda/envs/brandon_env/lib/python3.9/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     210                 if not self._wrap_exception and attempt.has_exception:
#     211                     # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 212                     raise attempt.get()
#     213                 else:
#     214                     raise RetryError(attempt)
#
# ~/.conda/envs/brandon_env/lib/python3.9/site-packages/retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~/.conda/envs/brandon_env/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~/.conda/envs/brandon_env/lib/python3.9/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# <ipython-input-12-8f7eb989cdf2> in scrape_slugs(slug)
#      13     repo = split_slugs[1]
#      14     fullfilename = os.path.join('/project/class/bii_sdad_dspg/ncses_oss_2021/', f'readme_{login}_{repo}.txt')
# ---> 15     urllib.request.urlretrieve(url, fullfilename)
#      16     now = datetime.now()
#      17     current_time = now.strftime("%H:%M:%S")
#
# ~/.conda/envs/brandon_env/lib/python3.9/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     237     url_type, path = _splittype(url)
#     238
# --> 239     with contextlib.closing(urlopen(url, data)) as fp:
#     240         headers = fp.info()
#     241
#
# ~/.conda/envs/brandon_env/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~/.conda/envs/brandon_env/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# ~/.conda/envs/brandon_env/lib/python3.9/urllib/request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# ~/.conda/envs/brandon_env/lib/python3.9/urllib/request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# ~/.conda/envs/brandon_env/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~/.conda/envs/brandon_env/lib/python3.9/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
pd.read_csv('data.csv')
# Out:
# 'uva-bi-sdad/oss-2020'

# %%
slugs = ["brandonleekramer/diversity", 
         "uva-bi-sdad/oss-2020", 
         "facebook/react", 
         "RichardLitt/standard-readme"
] 



slugs = ["brandonleekramer/diversity", "uva-bi-sdad/oss-2020", "facebook/react", "RichardLitt/standard-readme"] #test data 
#slugs = raw_slug_data.slug.tolist()

#myPath = '/sfs/qumulo/qhome/kb7hp/git/oss-2020/src/09_repository-scraping/' 
myPath = '/project/class/bii_sdad_dspg/ncses_oss_2021/'

for slug in slugs:
    url = f'https://github.com/{slug}#readme'
    split_slugs = slug.split("/")
    login = split_slugs[0]
    repo = split_slugs[1]
    fullfilename = os.path.join(myPath, f'readme_{login}_{repo}.txt')
    urllib.request.urlretrieve(url, fullfilename)
    print(f'Finished scraping: {login}/{repo}')
# Out:
# Finished scraping: brandonleekramer/diversity
# Finished scraping: uva-bi-sdad/oss-2020
# Finished scraping: facebook/react
# Finished scraping: RichardLitt/standard-readme

# %% [markdown]
# Note to Crystal:
#
# The function above this note works for small-scale scraping but we need to add in the rate limit on API calls before we scale up.
# https://stackoverflow.com/questions/40748687/python-api-rate-limiting-how-to-limit-api-calls-globally
#
# We could also try to add in multiprocessing to speed things up. I'm not sure this link is the right one, but we can chat more about that.
# https://stackoverflow.com/questions/54858979/how-to-use-multiprocessing-with-requests-module

# %%
myPath = '/project/class/bii_sdad_dspg/ncses_oss_2021/'

repo_name = []
readme_text = [] 
for filename in os.listdir(myPath):
    if filename.endswith('.txt'):
        with open(os.path.join(myPath, filename)) as f:
            content = f.read()
            soup = BeautifulSoup(content, 'html.parser')
            if soup.article is not None:
                clean_html = ''.join(soup.article.findAll(text=True))
            else: 
                clean_html = None 
            repo_name.append(filename)
            readme_text.append(clean_html)
            df = pd.DataFrame({'slug': repo_name, 'readme_text': readme_text}, columns=["slug", "readme_text"])
            df['slug'] = df['slug'].str.replace('readme_','')
            df['slug'] = df['slug'].str.replace('.txt','')
            # this works because slugs can't have underscores
            df['slug'] = df['slug'].str.replace('_','/') 
df
# Out:
#                                           slug  \
# 0                                Vinetos/emacs
# 1                               uemanet/eskada
# 2                    fieldstar/FoodRiskTracing
# 3                          Nkosi-tshawe/moodle
# 4                joshblack/carbon-experimental
# ...                                        ...
# 2091  ualberta-eclass/moodle-block/demostudent
# 2092                          MircomBAS/vscode
# 2093                      morenfang/tensorflow
# 2094                           jissong/AliRoot
# 2095                              vechain/thor
#
#                                             readme_text
# 0                                                  None
# 1                                                  None
# 2                                          BfROpenLab\n
# 3                                                  None
# 4     carbon-experimental\n\nAll work shown here is ...
# ...                                                 ...
# 2091                                               None
# 2092  Visual Studio Code - Open Source ("Code - OSS"...
# 2093  \n\n\n\n\n\nDocumentation\n\n\n\n\n\n\n\n\nTen...
# 2094                                               None
# 2095  VeChain Thor\nA general purpose blockchain hig...
#
# [2096 rows x 2 columns]

# %%
os.chdir('/project/class/bii_sdad_dspg/ncses_oss_2021/')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
merged_df = df.merge(combined_csv, how='inner', on='slug')
merged_df
# Out:
#                                     slug  \
# 0                          Vinetos/emacs
# 1          joshblack/carbon-experimental
# 2                 ledermann/docker-rails
# 3                     jackjack821/pytest
# 4            DamienIrving/ocean-analysis
# ..                                   ...
# 365                       gemian/connman
# 366                      keyteki/keyteki
# 367               tsuu32/emacs-w32con-vt
# 368  AjayBrahmakshatriya/llvm-bb-emitter
# 369                         vechain/thor
#
#                                            readme_text   batch     as_of  \
# 0                                                 None  batch1  16:59:00
# 1    carbon-experimental\n\nAll work shown here is ...  batch2   8:09:16
# 2    Docker-Rails\n\n\nSimple Rails 6.1 application...  batch2   8:09:16
# 3    \n\n\n\n\n\n\n\n\n\n\n\nThe pytest framework m...  batch2   8:09:15
# 4    README\nThis repository contains the code I us...  batch2   8:09:16
# ..                                                 ...     ...       ...
# 365                                               None  batch2   8:09:15
# 366  Keyteki\nWeb based implementation of Keyforge:...  batch2   8:09:15
# 367  Emacs with 256/true color support in Windows C...  batch1  16:58:59
# 368                                               None  batch1  16:57:59
# 369  VeChain Thor\nA general purpose blockchain hig...  batch2   8:10:17
#
#     status
# 0     Done
# 1     Done
# 2     Done
# 3     Done
# 4     Done
# ..     ...
# 365   Done
# 366   Done
# 367   Done
# 368   Done
# 369   Done
#
# [370 rows x 5 columns]

# %%
os.chdir('/sfs/qumulo/qhome/kb7hp/git/dspg21oss/data/')
merged_df.to_csv("readme_test_data.csv")

# %%
db_user = os.environ.get('db_user')
db_pwd = os.environ.get('db_pwd')
engine = create_engine('postgresql+psycopg2://{db_user}:{db_pwd}@postgis1/sdad')
merged_df.to_sql('repos_scraped', engine, schema='gh_2007_2020', if_exists='replace', index=False)
print("It worked")
# Out:
# It worked

# %% [markdown]
# We need to write this to the database now...
#
# Try this: https://medium.com/analytics-vidhya/part-3-5-pandas-dataframe-to-postgresql-using-python-d3bc41fcf39
#
# https://pybay.com/site_media/slides/raymond2017-keynote/process.html
#
# https://github.com/rholder/retrying
#
# https://stackoverflow.com/questions/45016816/updating-row-using-sqlalchemy-and-scrapy
#
# https://stackoverflow.com/questions/2712524/handling-urllib2s-timeout-python
#
# https://stackoverflow.com/questions/666022/what-errors-exceptions-do-i-need-to-handle-with-urllib2-request-urlopen

# %%
# connect to the database, download data 
connection = pg.connect(host = 'postgis1', 
                        database = 'sdad', 
                        user = os.environ.get('db_user'), 
                        password = os.environ.get('db_pwd'))

repos_scraped = '''SELECT * FROM gh_2007_2020.repos_scraped '''

# convert to a dataframe, show how many missing we have (none)
repos_scraped = pd.read_sql_query(repos_scraped, con=connection)
repos_scraped.head()
# Out:
#                             slug  \
# 0                  Vinetos/emacs
# 1  joshblack/carbon-experimental
# 2         ledermann/docker-rails
# 3             jackjack821/pytest
# 4    DamienIrving/ocean-analysis
#
#                                          readme_text   batch     as_of status
# 0                                               None  batch1  16:59:00   Done
# 1  carbon-experimental\n\nAll work shown here is ...  batch2   8:09:16   Done
# 2  Docker-Rails\n\n\nSimple Rails 6.1 application...  batch2   8:09:16   Done
# 3  \n\n\n\n\n\n\n\n\n\n\n\nThe pytest framework m...  batch2   8:09:15   Done
# 4  README\nThis repository contains the code I us...  batch2   8:09:16   Done
