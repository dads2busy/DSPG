# %% [markdown]
# # Topic Modeling

# %% [markdown]
# Author: Crystal

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import gensim
import time
import time

import nltk
import stanza
import gensim
import re

#topic modeling
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression as lm

import matplotlib.collections as mcol
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.lines import Line2D

import seaborn as sns

# %%
df = pd.read_csv("/project/class/bii_sdad_dspg/ncses_oss_2021/requests_scrape/oss_readme_aggregated/oss_readme_data_061521.csv")

df.reset_index(inplace = True)

# %%
df
# Out:
#        index                                          slug  \
# 0          0                       h2oota/emacs-win64-msvc
# 1          1                       Distrotech/mysql-server
# 2          2            DaichiUeura/Emacs-for-Windows--xj-
# 3          3                          httpgit12/jb4evea-16
# 4          4                     Tehsurfer/hugo-contrarian
# ...      ...                                           ...
# 52067  52067                       IonPostglacial/treegers
# 52068  52068                          TheSavior/PerfectBut
# 52069  52069                             kchivorn/angular2
# 52070  52070  jeffet/vehicle-manufacture-20180318202618486
# 52071  52071            ctrlplusb/react-universally-skinny
#
#                                              readme_text                batch  \
# 0      Copyright (C) 2001-2016 Free Software Foundati...  oss_readme_batch1_1
# 1      MySQL Server 5.6\r\n\r\nThis is a release of M...  oss_readme_batch1_1
# 2      Copyright (C) 2001, 2002, 2003, 2004, 2005, 20...  oss_readme_batch1_1
# 3      <img alt="Swift logo" height="70" src="https:/...  oss_readme_batch1_1
# 4      # Contrarian website\nThis website is the face...  oss_readme_batch1_1
# ...                                                  ...                  ...
# 52067            A RTS game using hexagonal grid maps.\n  oss_readme_batch1_9
# 52068                                                NaN  oss_readme_batch1_9
# 52069  # Angular QuickStart Source\n[![Build Status][...  oss_readme_batch1_9
# 52070  # Blockchain - Tutorial\n\nThis is the tutoria...  oss_readme_batch1_9
# 52071  ### DEPRECATED\n\nI am no longer managing this...  oss_readme_batch1_9
#
#                      as_of status
# 0            6/11/21 17:21   Done
# 1            6/11/21 17:21   Done
# 2            6/11/21 17:21   Done
# 3            6/11/21 17:21   Done
# 4            6/11/21 17:21   Done
# ...                    ...    ...
# 52067  2021-06-14 15:06:23   Done
# 52068  2021-06-14 15:06:24   Done
# 52069  2021-06-14 15:06:24   Done
# 52070  2021-06-14 15:06:23   Done
# 52071  2021-06-14 15:06:32   Done
#
# [52072 rows x 6 columns]

# %% [markdown]
# # Tokenization

# %%
# Create a stanza pipeline: this pipeline will tokenize, determine pos, 
# and then lemmatize the token appropriately.

nlp = stanza.Pipeline(lang='en',processors='tokenize,pos,lemma',tokenize_batch_size=500,lemma_batch_size=500,
                      use_gpu = True)

# Note - I thought about keeping the pos PART if the lemma was "not", ex) isn't --> be, not.  But due to the fact
# that we are using a bag-of-words model that does not take into account word order, this won't matter in the
# topic model.  So, this is not kept.


def token_pos_lemma(doc, pretokened=False, keep_numbers=True):
    
    # This function uses the pipeline to tokenize, find POS, and lemmatize a document
    
    """if pretokened, dont use this function, as it hasnt been adapted for it"""
    assert not pretokened #If these are already tokened per another pipeline, this function won't work correctly
    
    new_tokens=[]
     
    processed=nlp(doc)  # this is the line that does the tokenizing, pos, and lemmatizing
    
    for sent in processed.sentences:
        for word in sent.words:
            
            #If its a regular noun, verb, adj, or adverb, keep lemmatized form
            if word.pos in ['NOUN','VERB','ADJ','ADV']:
                new_tokens.append(word.lemma)
            
            #If you decided to retain numbers, their lemma is kept here. 
            #Note that number catching isnt perfect by this lemmatizing.
            elif word.pos=='NUM' and keep_numbers:
                new_tokens.append(word.lemma)
            
            #Exact phrases are kept here with no attempt at lemmatization: e.g. mars does not become mars, 
            #and hopefully scientific words e.g. chemicals will be tagged as propn, x, or intj if needed
            elif word.pos in ['PROPN','X','INTJ']: 
                new_tokens.append(word.text)
            
            #Note that no other tokens are kept        
       
    return new_tokens

token_pos_lemma("a text long hello wow i'm at mia's house studying.")
# Out:
# 2021-07-06 21:46:18 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-07-06 21:46:18 INFO: Use device: cpu
# 2021-07-06 21:46:18 INFO: Loading: tokenize
# 2021-07-06 21:46:18 INFO: Loading: pos
# 2021-07-06 21:46:18 INFO: Loading: lemma
# 2021-07-06 21:46:18 INFO: Done loading processors!
# ['text', 'long', 'hello', 'wow', "i'm", 'mia', 'house', 'study']

# %%
df_try = df.loc[1:1000,:]
df_try
# Out:
#       index                                slug  \
# 1         1             Distrotech/mysql-server
# 2         2  DaichiUeura/Emacs-for-Windows--xj-
# 3         3                httpgit12/jb4evea-16
# 4         4           Tehsurfer/hugo-contrarian
# 5         5                      jrockway/emacs
# ...     ...                                 ...
# 996     996       krg7880/json-schema-generator
# 997     997                   mobiusbyte/bumpit
# 998     998          vlingo-net/vlingo-net-http
# 999     999                      weakish/gister
# 1000   1000                      Vincit/dodo.js
#
#                                             readme_text                 batch  \
# 1     MySQL Server 5.6\r\n\r\nThis is a release of M...   oss_readme_batch1_1
# 2     Copyright (C) 2001, 2002, 2003, 2004, 2005, 20...   oss_readme_batch1_1
# 3     <img alt="Swift logo" height="70" src="https:/...   oss_readme_batch1_1
# 4     # Contrarian website\nThis website is the face...   oss_readme_batch1_1
# 5     Copyright (C) 2001, 2002, 2003, 2004, 2005, 20...   oss_readme_batch1_1
# ...                                                 ...                   ...
# 996   json-schema-generator\n=====================\n...  oss_readme_batch1_10
# 997   # bumpit\n[![CircleCI](https://circleci.com/gh...  oss_readme_batch1_10
# 998   # xoom-net-http\n\n[![Build status](https://ci...  oss_readme_batch1_10
# 999   gister\n======\n\n`gister` is a command line t...  oss_readme_batch1_10
# 1000  [![Build Status](https://travis-ci.org/Vincit/...  oss_readme_batch1_10
#
#                     as_of status
# 1           6/11/21 17:21   Done
# 2           6/11/21 17:21   Done
# 3           6/11/21 17:21   Done
# 4           6/11/21 17:21   Done
# 5           6/11/21 17:21   Done
# ...                   ...    ...
# 996   2021-06-14 15:15:29   Done
# 997   2021-06-14 15:15:29   Done
# 998   2021-06-14 15:15:29   Done
# 999   2021-06-14 15:15:29   Done
# 1000  2021-06-14 15:15:29   Done
#
# [1000 rows x 6 columns]

# %%
t1 = time.time()
#df_lemma = df_try.assign(readme_lemma= df_try["readme_text"].apply(lambda x: token_pos_lemma(x)))

lemma = []
lemma = df_try["readme_text"].apply(lambda x: token_pos_lemma(x))

t2 = time.time()

print(f"time spent: {t2-t1}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-d7035573945d> in <module>
#       3
#       4 lemma = []
# ----> 5 lemma = df_try["readme_text"].apply(lambda x: token_pos_lemma(x))
#       6
#       7 t2 = time.time()
#
# ~/.conda/envs/crystal_bert/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-7-d7035573945d> in <lambda>(x)
#       3
#       4 lemma = []
# ----> 5 lemma = df_try["readme_text"].apply(lambda x: token_pos_lemma(x))
#       6
#       7 t2 = time.time()
#
# <ipython-input-5-66361e207bf1> in token_pos_lemma(doc, pretokened, keep_numbers)
#      19     new_tokens=[]
#      20
# ---> 21     processed=nlp(doc)  # this is the line that does the tokenizing, pos, and lemmatizing
#      22
#      23     for sent in processed.sentences:
#
# ~/.conda/envs/crystal_bert/lib/python3.8/site-packages/stanza/pipeline/core.py in __call__(self, doc)
#     249
#     250     def __call__(self, doc):
# --> 251         assert any([isinstance(doc, str), isinstance(doc, list),
#     252                     isinstance(doc, Document)]), 'input should be either str, list or Document'
#     253         doc = self.process(doc)
#
# AssertionError: input should be either str, list or Document

# %%
df_try["readme_lemma"]= lemma

# %%
#df_try.to_pickle("/home/zz3hs/git/dspg21oss/data/dspg21oss/readme_lemma_try.pkl")
